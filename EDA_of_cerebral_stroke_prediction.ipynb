# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Step 1: Load the dataset

# %%
clean_data = pd.read_csv("clean_data.csv")
print("Dataset loaded with shape:", clean_data.shape)
print(clean_data.head())
# Out:
# Dataset loaded with shape: (30108, 11)
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  58.0             1              0          Yes        Private
# 1  Female  70.0             0              0          Yes        Private
# 2  Female  52.0             0              0          Yes        Private
# 3  Female  75.0             0              1          Yes  Self-employed
# 4  Female  32.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban              87.96  39.2     never smoked       0
# 1          Rural              69.04  35.9  formerly smoked       0
# 2          Urban              77.59  17.7  formerly smoked       0
# 3          Rural             243.53  27.0     never smoked       0
# 4          Rural              77.67  32.3           smokes       0

# %%
clean_data
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# 0        Male  58.0             1              0          Yes        Private
# 1      Female  70.0             0              0          Yes        Private
# 2      Female  52.0             0              0          Yes        Private
# 3      Female  75.0             0              1          Yes  Self-employed
# 4      Female  32.0             0              0          Yes        Private
# ...       ...   ...           ...            ...          ...            ...
# 30103  Female  10.0             0              0           No       children
# 30104  Female  56.0             0              0          Yes       Govt_job
# 30105  Female  82.0             1              0          Yes        Private
# 30106    Male  40.0             0              0          Yes        Private
# 30107  Female  82.0             0              0          Yes        Private
#
# ...

# %% [markdown]
# # Step 2: Exploratory Data Analysis (EDA)

# %%
clean_data.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  58.0             1              0          Yes        Private
# 1  Female  70.0             0              0          Yes        Private
# 2  Female  52.0             0              0          Yes        Private
# 3  Female  75.0             0              1          Yes  Self-employed
# 4  Female  32.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban              87.96  39.2     never smoked       0
# 1          Rural              69.04  35.9  formerly smoked       0
# 2          Urban              77.59  17.7  formerly smoked       0
# 3          Rural             243.53  27.0     never smoked       0
# 4          Rural              77.67  32.3           smokes       0

# %%
clean_data.tail()
# Out:
#        gender   age  hypertension  heart_disease ever_married work_type  \
# 30103  Female  10.0             0              0           No  children
# 30104  Female  56.0             0              0          Yes  Govt_job
# 30105  Female  82.0             1              0          Yes   Private
# 30106    Male  40.0             0              0          Yes   Private
# 30107  Female  82.0             0              0          Yes   Private
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 30103          Urban              58.64  20.4     never smoked       0
# 30104          Urban             213.61  55.4  formerly smoked       0
# 30105          Urban              91.94  28.9  formerly smoked       0
# 30106          Urban              99.16  33.2     never smoked       0
# 30107          Urban              79.48  20.6     never smoked       0

# %%
clean_data.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
clean_data.dtypes
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
clean_data.shape
# Out:
# (30108, 11)

# %%
clean_data.describe()
# Out:
#                 age  hypertension  heart_disease  avg_glucose_level  \
# count  30108.000000  30108.000000   30108.000000       30108.000000
# mean      47.935100      0.117178       0.055733         107.188866
# std       18.752146      0.321638       0.229409          45.963166
# min       10.000000      0.000000       0.000000          55.010000
# 25%       33.000000      0.000000       0.000000          77.837500
# 50%       48.000000      0.000000       0.000000          92.395000
# 75%       62.000000      0.000000       0.000000         114.492500
# max       82.000000      1.000000       1.000000         291.050000
#
#                 bmi        stroke
# count  30108.000000  30108.000000
# mean      30.004302      0.021190
# std        7.073984      0.144021
# min       10.100000      0.000000
# 25%       25.100000      0.000000
# 50%       28.700000      0.000000
# 75%       33.600000      0.000000
# max       92.000000      1.000000

# %%
clean_data.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# # Check duplicates

# %%
clean_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Drop duplicates

# %%
clean_data.drop_duplicates(inplace=True)
print('\nNumber of duplicates after dropping')
print(clean_data.duplicated().sum())
# Out:
# Number of duplicates after dropping
# 0

# %%
clean_data.dropna(inplace=True)

# %% [markdown]
# # Verify cleaned dataset

# %%
print('\nDataset info after cleaning:')
print(clean_data.info())
print('\nUpdated dataset:')
print(clean_data)
# Out:
# Dataset info after cleaning:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30108 entries, 0 to 30107
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             30108 non-null  object
#  1   age                30108 non-null  float64
#  2   hypertension       30108 non-null  int64
#  3   heart_disease      30108 non-null  int64
#  4   ever_married       30108 non-null  object
#  5   work_type          30108 non-null  object
#  6   Residence_type     30108 non-null  object
#  7   avg_glucose_level  30108 non-null  float64
#  8   bmi                30108 non-null  float64
#  9   smoking_status     30108 non-null  object
#  10  stroke             30108 non-null  int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 2.5+ MB
# None
#
# Updated dataset:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# ...

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30108 entries, 0 to 30107
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             30108 non-null  object
#  1   age                30108 non-null  float64
#  2   hypertension       30108 non-null  int64
#  3   heart_disease      30108 non-null  int64
#  4   ever_married       30108 non-null  object
#  5   work_type          30108 non-null  object
#  6   Residence_type     30108 non-null  object
#  7   avg_glucose_level  30108 non-null  float64
#  8   bmi                30108 non-null  float64
#  9   smoking_status     30108 non-null  object
#  10  stroke             30108 non-null  int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 2.5+ MB

# %% [markdown]
# # Step 4: Initial Exploratory Data Analysis (EDA)

# %% [markdown]
# # Summary statistics

# %%
print(clean_data.describe())
# Out:
#                 age  hypertension  heart_disease  avg_glucose_level  \
# count  30108.000000  30108.000000   30108.000000       30108.000000
# mean      47.935100      0.117178       0.055733         107.188866
# std       18.752146      0.321638       0.229409          45.963166
# min       10.000000      0.000000       0.000000          55.010000
# 25%       33.000000      0.000000       0.000000          77.837500
# 50%       48.000000      0.000000       0.000000          92.395000
# 75%       62.000000      0.000000       0.000000         114.492500
# max       82.000000      1.000000       1.000000         291.050000
#
#                 bmi        stroke
# count  30108.000000  30108.000000
# mean      30.004302      0.021190
# std        7.073984      0.144021
# min       10.100000      0.000000
# 25%       25.100000      0.000000
# 50%       28.700000      0.000000
# 75%       33.600000      0.000000
# max       92.000000      1.000000

# %% [markdown]
# # Stroke value counts

# %%
print(clean_data.stroke.value_counts())
# Out:
# stroke
# 0    29470
# 1      638
# Name: count, dtype: int64

# %% [markdown]
# ## Histogram of Features

# %%
fig=clean_data.hist(figsize=(10,10))
plt.savefig('images/histogram.png')
plt.show()

# %% [markdown]
# # Histograms for all numerical columns

# %%
clean_data.hist(figsize=(10, 10))
plt.savefig('images/numerical.png')
plt.show()

# %% [markdown]
# # Distribution of numerical columns with KDE

# %%
numerical_cols = clean_data.select_dtypes(include=[np.number]).columns

for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(clean_data[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.savefig(f'images/histogram_{col}.png')
    plt.show()
# Out:
# C:\Users\Default.DESKTOP-8TCQEDR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Default.DESKTOP-8TCQEDR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Default.DESKTOP-8TCQEDR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # Distribution of categorical columns

# %%
categorical_cols = clean_data.select_dtypes(include=['object']).columns

for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=clean_data, x=col)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.savefig(f'images/countplot_{col}.png')
    plt.show()

# %% [markdown]
# # Distribution of age groups

# %%
clean_data['age_group'] = pd.cut(clean_data['age'], bins=[0, 18, 35, 50, 65, 100], labels=['0-18', '19-35', '36-50', '51-65', '66+'])
plt.figure(figsize=(8, 4))
sns.countplot(data=clean_data, x='age_group')
plt.title('Distribution of Age Groups')
plt.savefig('images/age_group_distribution.png')
plt.show()
# Out:
# C:\Users\Default.DESKTOP-8TCQEDR\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# # Distribution of BMI categories

# %%
clean_data['bmi_category'] = pd.cut(clean_data['bmi'], bins=[0, 18.5, 24.9, 29.9, 100], labels=['Underweight', 'Normal', 'Overweight', 'Obese'])
plt.figure(figsize=(8, 4))
sns.countplot(data=clean_data, x='bmi_category')
plt.title('Distribution of BMI Categories')
plt.savefig('images/bmi_category_distribution.png')
plt.show()
# Out:
# C:\Users\Default.DESKTOP-8TCQEDR\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# # Distribution of glucose categories

# %%
clean_data['glucose_category'] = pd.cut(clean_data['avg_glucose_level'], bins=[0, 140, 200, 300], labels=['Normal', 'Prediabetes', 'Diabetes'])
plt.figure(figsize=(8, 4))
sns.countplot(data=clean_data, x='glucose_category')
plt.title('Distribution of Glucose Categories')
plt.savefig('images/glucose_category_distribution.png')
plt.show()
# Out:
# C:\Users\Default.DESKTOP-8TCQEDR\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# # Step 6: Correlation Analysis

# %%
# Calculate correlations only on numerical features
numerical_features = clean_data.select_dtypes(include=np.number).columns
correlation_matrix = clean_data[numerical_features].corr()

# Display the correlation matrix
print(correlation_matrix)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.savefig('images/correlation_matrix.png')
plt.show()
# Out:
#                         age  hypertension  heart_disease  avg_glucose_level  \
# age                1.000000      0.259528       0.251819           0.230682
# hypertension       0.259528      1.000000       0.114957           0.154702
# heart_disease      0.251819      0.114957       1.000000           0.139449
# avg_glucose_level  0.230682      0.154702       0.139449           1.000000
# bmi                0.101619      0.120730       0.018562           0.167699
# stroke             0.159838      0.073310       0.107007           0.077206
#
#                         bmi    stroke
# age                0.101619  0.159838
# hypertension       0.120730  0.073310
# heart_disease      0.018562  0.107007
# avg_glucose_level  0.167699  0.077206
# bmi                1.000000 -0.006950
# stroke            -0.006950  1.000000

# %% [markdown]
# # Pie chart of positive correlations

# %%
correlation_with_stroke = clean_data.corr(numeric_only=True)['stroke'].sort_values(ascending=False)
positive_corr = correlation_with_stroke[correlation_with_stroke >= 0]
positive_corr.plot(kind='pie', figsize=(8, 8))
plt.title('Positive Correlations with Stroke')
plt.savefig('images/positive_correlations_stroke.png')
plt.show()

# %% [markdown]
# # Step 7: Visualizing Distributions and Relationships

# %% [markdown]
# # Distribution of target variable 'stroke

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='stroke', data=clean_data, palette='Set2')
plt.title('Distribution of Stroke')
plt.xlabel('Stroke')
plt.ylabel('Count')
plt.savefig('images/stroke_distribution.png')
plt.show()

# %% [markdown]
# # Stroke occurrence by age

# %%
# Stroke occurrence by age
age_stroke = clean_data.groupby('age')['stroke'].mean().reset_index()
fig = px.line(age_stroke, x='age', y='stroke',
              title='Stroke Occurrence by Age',
              labels={'stroke': 'Probability of Stroke', 'age': 'Age'},
              markers=True)
fig.update_traces(line=dict(width=2))  # Thicker line for visibility
fig.write_image('images/stroke_occurrence_by_age.png')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 8
#       3 fig = px.line(age_stroke, x='age', y='stroke',
#       4               title='Stroke Occurrence by Age',
#       5               labels={'stroke': 'Probability of Stroke', 'age': 'Age'},
#       6               markers=True)
#       7 fig.update_traces(line=dict(width=2))  # Thicker line for visibility
# ----> 8 fig.write_image('images/stroke_occurrence_by_age.png')
#       9 fig.show()
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:3829, in BaseFigure.write_image(self, *args, **kwargs)
#    3769 """
#    3770 Convert a figure to a static image and write it to a file or writeable
#    3771 object
#    (...)
#    3825 None
#    3826 """
#    3827 import plotly.io as pio
# -> 3829 return pio.write_image(self, *args, **kwargs)
#
# ...

# %% [markdown]
# # Stroke probability by work type status

# %%
# Stroke probability by work type
worktype_stroke_probabilities = clean_data.groupby("work_type")["stroke"].mean().reset_index()
print("\nStroke Probabilities by Work Type:")
print(worktype_stroke_probabilities)
fig = px.bar(worktype_stroke_probabilities, x='work_type', y='stroke',
             title='Work Type vs Stroke Probability',
             labels={'stroke': 'Stroke Probability', 'work_type': 'Work Type'},
             color='work_type')
fig.write_image('images/work_type_stroke_probability.png')
fig.show()

# %% [markdown]
# ### Stroke probability by smoking status

# %%
# Stroke probability by smoking status
smoking_stroke_probabilities = clean_data.groupby("smoking_status")["stroke"].mean().reset_index()
print("\nStroke Probabilities by Smoking Status:")
print(smoking_stroke_probabilities)
fig = px.pie(smoking_stroke_probabilities, values='stroke',
             names='smoking_status',
             title='Stroke Probability by Smoking Status',
             color_discrete_sequence=px.colors.sequential.OrRd_r)
fig.write_image('images/smoking_status_stroke_probability.png')
fig.show()

# %% [markdown]
# # Stroke risk by age brackets

# %%
# Stroke risk by age brackets
plt.figure(figsize=(15, 10))  # Increase figure size for better spacing
age_bins = [0, 18, 30, 45, 60, 75, 90]
clean_data['age_group'] = pd.cut(clean_data['age'], bins=age_bins)
age_stroke = clean_data.groupby('age_group')['stroke'].mean().reset_index()
plt.subplot(2, 2, 1)
sns.barplot(x='age_group', y='stroke', data=age_stroke, palette='viridis')
plt.title('Stroke Probability by Age Group')
plt.xticks(rotation=45)
plt.xlabel('Age Group')
plt.ylabel('Stroke Probability')
plt.savefig('images/stroke_probability_by_age_group.png')
plt.show()

# %% [markdown]
# # Hypertension & heart disease interaction

# %%
# Hypertension & heart disease interaction
conditions = clean_data.groupby(['hypertension', 'heart_disease'])['stroke'].mean().reset_index()
conditions['condition'] = conditions.apply(lambda x:
    "Both+" if x['hypertension'] and x['heart_disease'] else
    "Hypertension+" if x['hypertension'] else
    "Heart Disease+" if x['heart_disease'] else
    "None", axis=1)
print("Stroke Probabilities by Medical Conditions:")
print(conditions)  # Verify data
plt.subplot(2, 2, 2)
sns.barplot(x='condition', y='stroke', data=conditions, palette='Set2')  # Switch to Set2 for distinct colors
plt.title('Stroke Risk by Medical Conditions')
plt.xlabel('Condition')
plt.ylabel('Stroke Probability')
plt.xticks(rotation=45, ha='right')  # Rotate and align labels to prevent overlap
plt.savefig('images/stroke_risk_by_medical_conditions.png')
plt.show()

# %% [markdown]
# # Glucose level impact

# %%
# Glucose level impact
glucose_bins = [0, 140, 200, 300]
clean_data['glucose_category'] = pd.cut(clean_data['avg_glucose_level'], bins=glucose_bins,
                                        labels=['Normal', 'Prediabetes', 'Diabetes'])
glucose_stroke = clean_data.groupby('glucose_category')['stroke'].mean().reset_index()
plt.subplot(2, 2, 3)
sns.barplot(x='glucose_category', y='stroke', data=glucose_stroke, palette='Blues')
plt.title('Stroke Risk by Glucose Levels')
plt.xlabel('Glucose Category')
plt.ylabel('Stroke Probability')
plt.xticks(rotation=45, ha='right')
plt.savefig('images/glucose_level.png')
plt.show()

# %% [markdown]
# # BMI categories analysis

# %%
# BMI categories analysis
bmi_bins = [0, 18.5, 25, 30, 100]
clean_data['bmi_category'] = pd.cut(clean_data['bmi'], bins=bmi_bins,
                                    labels=['Underweight', 'Normal', 'Overweight', 'Obese'])
bmi_stroke = clean_data.groupby('bmi_category')['stroke'].mean().reset_index()
plt.subplot(2, 2, 4)
sns.barplot(x='bmi_category', y='stroke', data=bmi_stroke, palette='rocket')
plt.title('Stroke Risk by BMI Category')
plt.xlabel('BMI Category')
plt.ylabel('Stroke Probability')
plt.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.savefig('images/Stroke_Risk_by_BMI_Category.png')
plt.show()

# %% [markdown]
# # Residence type comparison

# %%
# Residence type comparison
plt.figure(figsize=(8, 5))
residence_stroke = clean_data.groupby('Residence_type')['stroke'].mean().reset_index()
sns.barplot(x='Residence_type', y='stroke', data=residence_stroke, palette='Set2')
plt.title('Urban vs Rural Stroke Rates')
plt.xlabel('Residence Type')
plt.ylabel('Stroke Probability')
plt.savefig('images/urban_vs_rural_stroke_rates.png')
plt.show()

# %% [markdown]
# # Marital status analysis

# %%
# Marital status and gender analysis
plt.figure(figsize=(10, 6))
sns.barplot(x='ever_married', y='stroke', hue='gender', data=clean_data, palette='Pastel1')
plt.title('Stroke Risk by Marital Status and Gender')
plt.xlabel('Ever Married')
plt.ylabel('Stroke Probability')
plt.savefig('images/stroke_risk_by_marital_status_and_gender.png')  # Saves in 'images' folder
plt.show()

# %% [markdown]
# # Stroke probability for hypertension patients

# %%
# Stroke probability for hypertension patients
hypertension_df = clean_data[clean_data['hypertension'] == 1]
hypertension_stroke_prob = hypertension_df.groupby(['gender', 'age'])['stroke'].mean().reset_index()
print("\nStroke Probability for Individuals with Hypertension:")
print(hypertension_stroke_prob)
fig = px.density_heatmap(hypertension_stroke_prob, x='age', y='gender', z='stroke',
                         title='Stroke Probability by Age and Gender (With Hypertension)',
                         labels={'stroke': 'Stroke Probability'},
                         color_continuous_scale='Reds')
fig.write_image('images/stroke_probability_by_age_and_gender_with_hypertension.png')
fig.show()

# %% [markdown]
# # Age group analysis for stroke occurrences

# %%
# Age group analysis for stroke occurrences
age_bins = [0, 18, 35, 50, 65, 100]
age_labels = ['<18', '18-35', '35-50', '50-65', '65+']
clean_data['age_group'] = pd.cut(clean_data['age'], bins=age_bins, labels=age_labels, right=False)
stroke_data = clean_data[clean_data['stroke'] == 1]
plt.figure(figsize=(12, 7))
ax = sns.countplot(data=stroke_data, x='age_group', hue='gender', palette='Set2', order=age_labels)
plt.title('Distribution of Stroke Occurrences across Age Groups and Genders', fontsize=14)
plt.xlabel('Age Group', fontsize=12)
plt.ylabel('Stroke Count', fontsize=12)
plt.legend(title='Gender', fontsize=10)
for p in ax.patches:
    height = p.get_height()
    if not np.isnan(height) and height > 0:
        ax.text(p.get_x() + p.get_width()/2., height + 0.1,
                int(height),
                ha="center", fontsize=10, fontweight='bold')
plt.tight_layout()
plt.savefig('images/age_gender_stroke_occurrences.png')
plt.show()

# %%
# Handle missing values in smoking_status (moved from preprocessing if not already done)
print("Missing smoking_status values: " + str(clean_data['smoking_status'].isna().sum()) + " out of " + str(len(clean_data)) + " rows")
clean_data['smoking_status'] = clean_data['smoking_status'].fillna('Unknown')
glucose_by_work_smoking = clean_data.groupby(['work_type', 'smoking_status'])['avg_glucose_level'].mean().reset_index()
pivot_table = glucose_by_work_smoking.pivot(index='work_type', columns='smoking_status', values='avg_glucose_level')
print("\nAverage Glucose Levels by Work Type and Smoking Status:")
print(pivot_table)
plt.figure(figsize=(14, 8))
ax = sns.barplot(x='work_type', y='avg_glucose_level', hue='smoking_status', data=glucose_by_work_smoking, palette='viridis')
plt.title('Impact of Work Type and Smoking Status on Average Glucose Levels', fontsize=16)
plt.xlabel('Work Type', fontsize=14)
plt.ylabel('Average Glucose Level (mg/dL)', fontsize=14)
plt.legend(title='Smoking Status', fontsize=12)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)
for p in ax.patches:
    height = p.get_height()
    if not np.isnan(height):
        ax.text(p.get_x() + p.get_width()/2., height + 0.3, f'{height:.1f}', ha="center", fontsize=10)
plt.tight_layout()
plt.savefig('images/glucose_by_work_smoking.png')
plt.show()

# %% [markdown]
# ###Stroke Probability by Smoking Status, BMI, and Glucose Levels

# %%
# Define BMI categories (consistent with #9)
bmi_bins = [0, 18.5, 25, 30, 100]
bmi_labels = ['Underweight', 'Normal', 'Overweight', 'Obese']
clean_data['bmi_bracket'] = pd.cut(clean_data['bmi'], bins=bmi_bins, labels=bmi_labels, right=False)

# Define glucose level categories (aligned with #8 for consistency)
glucose_bins = [0, 140, 200, 300]  # Match #8
glucose_labels = ['Normal', 'Prediabetes', 'Diabetes']
clean_data['glucose_bracket'] = pd.cut(clean_data['avg_glucose_level'], bins=glucose_bins, labels=glucose_labels)

# Ensure smoking_status has no missing values (from #14)
clean_data['smoking_status'] = clean_data['smoking_status'].fillna('Unknown')

# Grouping
stroke_by_smoking_bmi_glucose = clean_data.groupby(['smoking_status', 'bmi_bracket', 'glucose_bracket'])['stroke'].mean().reset_index()
filtered_df = stroke_by_smoking_bmi_glucose[stroke_by_smoking_bmi_glucose['glucose_bracket'] == 'Diabetes']

# Plot
plt.figure(figsize=(16, 8))
ax = sns.barplot(x='smoking_status', y='stroke', hue='bmi_bracket', data=filtered_df, palette='coolwarm')
plt.title('Stroke Probability by Smoking Status and BMI (Diabetes Only)')
plt.xlabel('Smoking Status')
plt.ylabel('Stroke Probability')
plt.xticks(rotation=45)
for p in ax.patches:
    height = p.get_height()
    if not np.isnan(height):
        ax.annotate(f'{height:.2f}',
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')
plt.legend(title='BMI Category')
plt.tight_layout()
plt.savefig('images/stroke_probability_by_smoking_bmi_glucose.png')
plt.show()
